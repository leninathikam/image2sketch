# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import cv2

# %% [markdown]
# # READING THE IMAGE

# %%
image1 = cv2.imread(r"C:\Users\Raju\Pictures\bird.jpg")
cv2.imshow("Beautiful Bird", image1)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![bird.jpg](attachment:bird.jpg)

# %% [markdown]
# # CONVERTING TO GREYSCALE

# %%
gray_image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
cv2.imshow("New Beautiful Bird", gray_image1)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![Capture1.JPG](attachment:Capture1.JPG)

# %% [markdown]
# # INVERTING THE GREYSCALE IMAGE

# %%
inverted_image1 = 255 - gray_image1
cv2.imshow("Inverted1", inverted_image1)
cv2.waitKey()
# Out:
# -1

# %% [markdown]
# ![Capture2.JPG](attachment:Capture2.JPG)

# %% [markdown]
# # BLUR THE IMAGE

# %%
blurred1 = cv2.GaussianBlur(inverted_image1, (21, 21), 0)

# %% [markdown]
# # Inverting the blurred image

# %%
inverted_blurred1 = 255 - blurred1
pencil_sketch1 = cv2.divide(gray_image1, inverted_blurred1, scale=256.0)
cv2.imshow("Sketch1", pencil_sketch1)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![Capture4.JPG](attachment:Capture4.JPG)

# %% [markdown]
# # original image and pencil sketch aside

# %%
cv2.imshow("original image1", image1)
cv2.imshow("pencil sketch1", pencil_sketch1)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![bird.jpg](attachment:bird.jpg)

# %% [markdown]
# ![Capture4.JPG](attachment:Capture4.JPG)
